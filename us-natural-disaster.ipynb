# %% [markdown]
# ## Prediksi Bencana Alam di US

# %% [markdown]
# nama dan nim
# Ryo Altius Benito - 71190417
# Yacinthus Dheka Pratomo Putro - 71190423
# Renaldi Kristian Hartono - 71190424
# Mishael Elian Dharmawan - 71190441

# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib as plt
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv('us_disaster_declarations.csv')
df.head(10)
# Out:
#   fema_declaration_string  disaster_number state declaration_type  \
# 0                 DR-1-GA                1    GA               DR
# 1                 DR-2-TX                2    TX               DR
# 2                 DR-3-LA                3    LA               DR
# 3                 DR-4-MI                4    MI               DR
# 4                 DR-5-MT                5    MT               DR
# 5                 DR-6-MI                6    MI               DR
# 6                 DR-7-MA                7    MA               DR
# 7                 DR-8-IA                8    IA               DR
# 8                 DR-9-TX                9    TX               DR
# 9                DR-11-NH               11    NH               DR
#
#        declaration_date  fy_declared incident_type         declaration_title  \
# 0  1953-05-02T00:00:00Z         1953       Tornado                   Tornado
# 1  1953-05-15T00:00:00Z         1953       Tornado  Tornado & Heavy Rainfall
# ...

# %% [markdown]
# # Bencana alam yang sering terjadi di US

# %% [markdown]
# hitung rata-rata

# %% [markdown]
# hitung kemungkinan terjadi tornado tiap quarter

# %%
disaster_types = df['incident_type'].unique()
# print("Types of Disasters reported:\n\n", disaster_types)    
# df.loc[df['column_name'].isin(some_values)]
# print("Occurrences:\n\n",df.loc[df['incident_type']== 'Tornado'][['declaration_date','incident_type']])

tornadoDate= pd.DataFrame()
tornadoDateQ1= 0
tornadoDateQ2= 0
tornadoDateQ3= 0
tornadoDateQ4= 0
#1953-05-02T00:00:00Z
for i, row in df.iterrows():
    if int(row['declaration_date'][5:7]) <= 3 and row['incident_type']== 'Tornado':
        tornadoDateQ1+=1
    elif int(row['declaration_date'][5:7]) > 3 and int(row['declaration_date'][5:7]) <= 6 and row['incident_type']== 'Tornado':
        tornadoDateQ2+=1
    elif int(row['declaration_date'][5:7]) > 6 and int(row['declaration_date'][5:7]) <= 9 and row['incident_type']== 'Tornado':
        tornadoDateQ3+=1
    elif int(row['declaration_date'][5:7]) > 9 and int(row['declaration_date'][5:7]) <= 12 and row['incident_type']== 'Tornado':
        tornadoDateQ4+=1
        
#laporan 
print("quarter1 =",tornadoDateQ1,"\nquarter2 =",tornadoDateQ2,"\nquarter3 =",tornadoDateQ3,"\nquarter4 =",tornadoDateQ4)
# Out:
# quarter1 = 246
# quarter2 = 873
# quarter3 = 256
# quarter4 = 196

# %% [markdown]
# hitung kemungkinan terjadi hurricane tiap quarter

# %%
HurricaneDate= pd.DataFrame()
HurricaneDateQ1= 0
HurricaneDateQ2= 0
HurricaneDateQ3= 0
HurricaneDateQ4= 0
#1953-05-02T00:00:00Z
for i, row in df.iterrows():
    if int(row['declaration_date'][5:7]) <= 3 and row['incident_type']== 'Hurricane':
        HurricaneDateQ1+=1
    elif int(row['declaration_date'][5:7]) > 3 and int(row['declaration_date'][5:7]) <= 6 and row['incident_type']== 'Hurricane':
        HurricaneDateQ2+=1
    elif int(row['declaration_date'][5:7]) > 6 and int(row['declaration_date'][5:7]) <= 9 and row['incident_type']== 'Hurricane':
        HurricaneDateQ3+=1
    elif int(row['declaration_date'][5:7]) > 9 and int(row['declaration_date'][5:7]) <= 12 and row['incident_type']== 'Hurricane':
        HurricaneDateQ4+=1
        
#laporan 
print("quarter1 =",HurricaneDateQ1,"\nquarter2 =",HurricaneDateQ2,"\nquarter3 =",HurricaneDateQ3,"\nquarter4 =",HurricaneDateQ4)
# Out:
# quarter1 = 130
# quarter2 = 27
# quarter3 = 10052
# quarter4 = 2282

# %% [markdown]
# hitung kemungkinan terjadi serve storm tiap quarter

# %%
SevereStorms= pd.DataFrame()
SevereStormsQ1= 0
SevereStormsQ2= 0
SevereStormsQ3= 0
SevereStormsQ4= 0
#1953-05-02T00:00:00Z
for i, row in df.iterrows():
    if int(row['declaration_date'][5:7]) <= 3 and row['incident_type']== 'Severe Storm(s)':
        SevereStormsQ1+=1
    elif int(row['declaration_date'][5:7]) > 3 and int(row['declaration_date'][5:7]) <= 6 and row['incident_type']== 'Severe Storm(s)':
        SevereStormsQ2+=1
    elif int(row['declaration_date'][5:7]) > 6 and int(row['declaration_date'][5:7]) <= 9 and row['incident_type']== 'Severe Storm(s)':
        SevereStormsQ3+=1
    elif int(row['declaration_date'][5:7]) > 9 and int(row['declaration_date'][5:7]) <= 12 and row['incident_type']== 'Severe Storm(s)':
        SevereStormsQ4+=1
        
#laporan 
print("quarter1 =",SevereStormsQ1,"\nquarter2 =",SevereStormsQ2,"\nquarter3 =",SevereStormsQ3,"\nquarter4 =",SevereStormsQ4)
# Out:
# quarter1 = 5019
# quarter2 = 6220
# quarter3 = 4213
# quarter4 = 1838

# %% [markdown]
# hitung kemungkinan terjadi thypon tiap quarter

# %%
Typhoon= pd.DataFrame()
TyphoonQ1= 0
TyphoonQ2= 0
TyphoonQ3= 0
TyphoonQ4= 0
#1953-05-02T00:00:00Z
for i, row in df.iterrows():
    if int(row['declaration_date'][5:7]) <= 3 and row['incident_type']== 'Typhoon':
        TyphoonQ1+=1
    elif int(row['declaration_date'][5:7]) > 3 and int(row['declaration_date'][5:7]) <= 6 and row['incident_type']== 'Typhoon':
        TyphoonQ2+=1
    elif int(row['declaration_date'][5:7]) > 6 and int(row['declaration_date'][5:7]) <= 9 and row['incident_type']== 'Typhoon':
        TyphoonQ3+=1
    elif int(row['declaration_date'][5:7]) > 9 and int(row['declaration_date'][5:7]) <= 12 and row['incident_type']== 'Typhoon':
        TyphoonQ4+=1
#laporan 
print("quarter1 =",TyphoonQ1,"\nquarter2 =",TyphoonQ2,"\nquarter3:",TyphoonQ3,"\nquarter4 =",TyphoonQ4)
# Out:
# quarter1 = 32
# quarter2 = 10
# quarter3: 20
# quarter4 = 68

# %% [markdown]
# hitung kemungkinan terjadi drought tiap quarter

# %%
Drought= pd.DataFrame()
DroughtQ1= 0
DroughtQ2= 0
DroughtQ3= 0
DroughtQ4= 0
#1953-05-02T00:00:00Z
for i, row in df.iterrows():
    if int(row['declaration_date'][5:7]) <= 3 and row['incident_type']== 'Drought':
        DroughtQ1+=1
    elif int(row['declaration_date'][5:7]) > 3 and int(row['declaration_date'][5:7]) <= 6 and row['incident_type']== 'Drought':
        DroughtQ2+=1
    elif int(row['declaration_date'][5:7]) > 6 and int(row['declaration_date'][5:7]) <= 9 and row['incident_type']== 'Drought':
        DroughtQ3+=1
    elif int(row['declaration_date'][5:7]) > 9 and int(row['declaration_date'][5:7]) <= 12 and row['incident_type']== 'Drought':
        DroughtQ4+=1
        
#laporan 
print("quarter1 =",DroughtQ1,"\nquarter2 =",DroughtQ2,"\nquarter3 =",DroughtQ3,"\nquarter4 =",DroughtQ4)
# Out:
# quarter1 = 226
# quarter2 = 261
# quarter3 = 713
# quarter4 = 92

# %% [markdown]
# hitung kemungkinan terjadi snow tiap quarter

# %%
Snow= pd.DataFrame()
SnowQ1= 0
SnowQ2= 0
SnowQ3= 0
SnowQ4= 0
#1953-05-02T00:00:00Z
for i, row in df.iterrows():
    if int(row['declaration_date'][5:7]) <= 3 and row['incident_type']== 'Snow':
        SnowQ1+=1
    elif int(row['declaration_date'][5:7]) > 3 and int(row['declaration_date'][5:7]) <= 6 and row['incident_type']== 'Snow':
        SnowQ2+=1
    elif int(row['declaration_date'][5:7]) > 6 and int(row['declaration_date'][5:7]) <= 9 and row['incident_type']== 'Snow':
        SnowQ3+=1
    elif int(row['declaration_date'][5:7]) > 9 and int(row['declaration_date'][5:7]) <= 12 and row['incident_type']== 'Snow':
        SnowQ4+=1
        
#laporan 
print("quarter1=",SnowQ1,"\nquarter2 =",SnowQ2,"\nquarter3 =",SnowQ3,"\nquarter4 =",SnowQ4)
# Out:
# quarter1= 3145
# quarter2 = 409
# quarter3 = 33
# quarter4 = 109

# %% [markdown]
# hitung kemungkinan terjadi serve ice storm tiap quarter

# %%
SevereIceStorm= pd.DataFrame()
SevereIceStormQ1= 0
SevereIceStormQ2= 0
SevereIceStormQ3= 0
SevereIceStormQ4= 0
#1953-05-02T00:00:00Z
for i, row in df.iterrows():
    if int(row['declaration_date'][5:7]) <= 3 and row['incident_type']== 'SevereIceStorm':
        SevereIceStormQ1+=1
    elif int(row['declaration_date'][5:7]) > 3 and int(row['declaration_date'][5:7]) <= 6 and row['incident_type']== 'Severe Ice Storm':
        SevereIceStormQ2+=1
    elif int(row['declaration_date'][5:7]) > 6 and int(row['declaration_date'][5:7]) <= 9 and row['incident_type']== 'Severe Ice Storm':
        SevereIceStormQ3+=1
    elif int(row['declaration_date'][5:7]) > 9 and int(row['declaration_date'][5:7]) <= 12 and row['incident_type']== 'Severe Ice Storm':
        SevereIceStormQ4+=1
        
#laporan 
print("quarter1 =",SevereIceStormQ1,"\nquarter2 =",SevereIceStormQ2,"\nquarter3 =",SevereIceStormQ3,"\nquarter4 =",SevereIceStormQ4)
# Out:
# quarter1 = 0
# quarter2 = 195
# quarter3 = 7
# quarter4 = 568

# %% [markdown]
# hitung kemungkinan terjadi freezing tiap quarter

# %%
Freezing= pd.DataFrame()
FreezingQ1= 0
FreezingQ2= 0
FreezingQ3= 0
FreezingQ4= 0
#1953-05-02T00:00:00Z
for i, row in df.iterrows():
    if int(row['declaration_date'][5:7]) <= 3 and row['incident_type']== 'Freezing':
        FreezingQ1+=1
    elif int(row['declaration_date'][5:7]) > 3 and int(row['declaration_date'][5:7]) <= 6 and row['incident_type']== 'Freezing':
        FreezingQ2+=1
    elif int(row['declaration_date'][5:7]) > 6 and int(row['declaration_date'][5:7]) <= 9 and row['incident_type']== 'Freezing':
        FreezingQ3+=1
    elif int(row['declaration_date'][5:7]) > 9 and int(row['declaration_date'][5:7]) <= 12 and row['incident_type']== 'Freezing':
        FreezingQ4+=1
        
#laporan 
print("quarter1:",FreezingQ1,"\nquarter2 =",FreezingQ2,"\nquarter3 =",FreezingQ3,"\nquarter4 =",FreezingQ4)
# Out:
# quarter1: 260
# quarter2 = 41
# quarter3 = 0
# quarter4 = 0

# %% [markdown]
# hitung kemungkinan terjadi coastal storm quarter

# %%
CoastalStorm= pd.DataFrame()
CoastalStormQ1= 0
CoastalStormQ2= 0
CoastalStormQ3= 0
CoastalStormQ4= 0
#1953-05-02T00:00:00Z
for i, row in df.iterrows():
    if int(row['declaration_date'][5:7]) <= 3 and row['incident_type']== 'CoastalStorm':
        CoastalStormQ1+=1
    elif int(row['declaration_date'][5:7]) > 3 and int(row['declaration_date'][5:7]) <= 6 and row['incident_type']== 'Coastal Storm':
        CoastalStormQ2+=1
    elif int(row['declaration_date'][5:7]) > 6 and int(row['declaration_date'][5:7]) <= 9 and row['incident_type']== 'Coastal Storm':
        CoastalStormQ3+=1
    elif int(row['declaration_date'][5:7]) > 9 and int(row['declaration_date'][5:7]) <= 12 and row['incident_type']== 'Coastal Storm':
        CoastalStormQ4+=1
        
#laporan 
print("quarter1 =",CoastalStormQ1,"\nquarter2 =",CoastalStormQ2,"\nquarter3 =",CoastalStormQ3,"\nquarter4 =",CoastalStormQ4)
# Out:
# quarter1 = 0
# quarter2 = 139
# quarter3 = 415
# quarter4 = 33

# %% [markdown]
# hitung kemungkinan terjadi tsunami tiap quarter

# %%
CoastalStorm= pd.DataFrame()
CoastalStormQ1= 0
CoastalStormQ2= 0
CoastalStormQ3= 0
CoastalStormQ4= 0
#1953-05-02T00:00:00Z
for i, row in df.iterrows():
    if int(row['declaration_date'][5:7]) <= 3 and row['incident_type']== 'CoastalStorm':
        CoastalStormQ1+=1
    elif int(row['declaration_date'][5:7]) > 3 and int(row['declaration_date'][5:7]) <= 6 and row['incident_type']== 'Coastal Storm':
        CoastalStormQ2+=1
    elif int(row['declaration_date'][5:7]) > 6 and int(row['declaration_date'][5:7]) <= 9 and row['incident_type']== 'Coastal Storm':
        CoastalStormQ3+=1
    elif int(row['declaration_date'][5:7]) > 9 and int(row['declaration_date'][5:7]) <= 12 and row['incident_type']== 'Coastal Storm':
        CoastalStormQ4+=1
        
#laporan 
print("quarter1 =",CoastalStormQ1,"\nquarter2 =",CoastalStormQ2,"\nquarter3 =",CoastalStormQ3,"\nquarter4 =",CoastalStormQ4)
# Out:
# quarter1 = 0
# quarter2 = 139
# quarter3 = 415
# quarter4 = 33

# %% [markdown]
# jadikan persentase per quarter

# %% [markdown]
# **Output**

# %%
totalQuarter1= tornadoDateQ1 + HurricaneDateQ1 + TyphoonQ1 + SevereStormsQ1 + DroughtQ1 + SnowQ1 + SevereIceStormQ1 + FreezingQ1 + CoastalStormQ1
totalQuarter2= tornadoDateQ2 + HurricaneDateQ2 + TyphoonQ2 + SevereStormsQ2 + DroughtQ2 + SnowQ2 + SevereIceStormQ2 + FreezingQ2 + CoastalStormQ2
totalQuarter3= tornadoDateQ3 + HurricaneDateQ3 + TyphoonQ3 + SevereStormsQ3 + DroughtQ3 + SnowQ3 + SevereIceStormQ3 + FreezingQ3 + CoastalStormQ3
totalQuarter4= tornadoDateQ4 + HurricaneDateQ4 + TyphoonQ4 + SevereStormsQ4 + DroughtQ4 + SnowQ4 + SevereIceStormQ4 + FreezingQ4 + CoastalStormQ4

totalAll= totalQuarter1 + totalQuarter2 + totalQuarter3 + totalQuarter4

# %%
index = ['quarter1','quarter2','quarter3','quarter4'] 
tornado = [tornadoDateQ1/totalAll*100,tornadoDateQ2/totalAll*100,tornadoDateQ3/totalAll*100,tornadoDateQ4/totalAll*100] 
hurricane = [HurricaneDateQ1/totalAll*100,HurricaneDateQ2/totalAll*100,HurricaneDateQ3/totalAll*100,HurricaneDateQ4/totalAll*100] 
typhoon = [TyphoonQ1/totalAll*100,TyphoonQ2/totalAll*100,TyphoonQ3/totalAll*100,TyphoonQ4/totalAll*100] 
severestorms = [SevereStormsQ1/totalAll*100,SevereStormsQ2/totalAll*100,SevereStormsQ3/totalAll*100,SevereStormsQ4/totalAll*100] 
drought = [DroughtQ1/totalAll*100,DroughtQ2/totalAll*100,DroughtQ3/totalAll*100,DroughtQ4/totalAll*100] 
snow = [SnowQ1/totalAll*100,SnowQ2/totalAll*100,SnowQ3/totalAll*100,SnowQ4/totalAll*100] 
severeicestorm = [SevereIceStormQ1/totalAll*100,SevereIceStormQ2/totalAll*100,SevereIceStormQ3/totalAll*100,SevereIceStormQ4/totalAll*100] 
freezing = [FreezingQ1/totalAll*100,FreezingQ2/totalAll*100,FreezingQ3/totalAll*100,FreezingQ4/totalAll*100] 
coastalstorm = [CoastalStormQ1/totalAll*100/totalAll*100,CoastalStormQ2/totalAll*100,CoastalStormQ3/totalAll*100,CoastalStormQ4/totalAll*100] 
 
df = pd.DataFrame({'tornado': tornado, 'hurricane':hurricane, 'typhoon':typhoon,'severestorms':severestorms, 
                  'drought':drought, 'snow':snow, 'severeicestorm':severeicestorm,'freezing':freezing, 
                   'coastalstorm':coastalstorm},index=index) 
df.plot.bar(stacked=True,figsize=(19,10))
# Out:
# 0.6451951321863197
